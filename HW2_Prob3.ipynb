# %% [markdown]
# # HW2 Colab Starter — CIFAR-10 Classification (5 epochs, tiny subset)
# *Compute Diary:* Run the next cell at the start and end of each session. Keep total GPU time ≤ **90 minutes**.

# %%
from datetime import datetime
import os, json
stamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
os.makedirs("diary", exist_ok=True)
with open("diary/compute_diary.txt", "a") as f:
    f.write(json.dumps({"event": "timestamp", "when": stamp}) + "\n")
print("⏱️ Compute diary timestamp:", stamp)
# Out:
# ⏱️ Compute diary timestamp: 2025-11-24 00:28:08

# %% [markdown]
# ## 0) Environment & GPU check

# %%
import torch, platform
print("Python:", platform.python_version())
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: 3.12.12
# Torch: 2.9.0+cu126
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## 1) Reproducibility (fixed seeds)

# %%
import random, numpy as np, torch
def set_seed(seed=0):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(0); print("✅ Seeds set to 0")
# Out:
# ✅ Seeds set to 0

# %% [markdown]
# ## 2) Data (CIFAR-10, fixed tiny subset)
# - Use at most **20%** of the training set (change `SUBSET_FRACTION` if needed).
# - Batch size ≤ 64.

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
import numpy as np

SUBSET_FRACTION = 0.2   # set to 0.1 for even faster runs
BATCH_SIZE = 64

tfm_train = transforms.Compose([transforms.RandomHorizontalFlip(), transforms.ToTensor()])
tfm_test  = transforms.ToTensor()

root = "./data"
train_full = datasets.CIFAR10(root, train=True, download=True, transform=tfm_train)
test_set   = datasets.CIFAR10(root, train=False, download=True, transform=tfm_test)

rng = np.random.default_rng(0)
subset_size = int(len(train_full) * SUBSET_FRACTION)
subset_idx = rng.choice(len(train_full), size=subset_size, replace=False)
train_set = Subset(train_full, subset_idx)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_set,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print("Train subset:", len(train_set), " Test:", len(test_set))
# Out:
# 100%|██████████| 170M/170M [00:14<00:00, 12.2MB/s]
# Train subset: 10000  Test: 10000

# %% [markdown]
# ## 3) Model (ResNet18) + 5-epoch training cap

# %%
import torch, torch.nn as nn
from torchvision.models import resnet18
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def make_model():
    m = resnet18(num_classes=10)
    return m.to(device)
EPOCHS = 5
LR = 1e-3

def train_one_config(optimizer_name="adam", use_cosine=False):
    model = make_model()
    if optimizer_name == "sgd":
        opt = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.9)
    else:
        opt = torch.optim.Adam(model.parameters(), lr=LR)
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS) if use_cosine else None
    criterion = nn.CrossEntropyLoss()
    history = {"train_loss": [], "test_acc": []}
    for epoch in range(1, EPOCHS+1):
        model.train(); running=0.0
        for x,y in train_loader:
            x,y = x.to(device), y.to(device)
            opt.zero_grad(); out = model(x); loss = criterion(out,y); loss.backward(); opt.step()
            running += loss.item()*x.size(0)
        train_loss = running/len(train_loader.dataset)
        model.eval(); correct=0; total=0
        with torch.no_grad():
            for x,y in test_loader:
                x,y = x.to(device), y.to(device)
                pred = model(x).argmax(1); correct += (pred==y).sum().item(); total += y.size(0)
        acc = correct/total
        if sched: sched.step()
        history["train_loss"].append(train_loss); history["test_acc"].append(acc)
        print(f"Epoch {epoch:02d} | loss={train_loss:.4f} | acc={acc:.3f}")
    return history
print("✅ Training utilities ready.")
# Out:
# ✅ Training utilities ready.

# %% [markdown]
# ## 4) Run two short ablations (pick two knobs)

# %%
# results = {}
# print("Run A: Adam + cosine"); results["adam_cosine"] = train_one_config("adam", True)
# print("\nRun B: SGD + const");  results["sgd_const"]  = train_one_config("sgd", False)
results = {}
print("Run A: Adam + cosine");  results["adam_cosine"] = train_one_config("adam", True)
print("\nRun B: Adam + const");  results["adam_const"] = train_one_config("adam", False)
print("\nRun C: SGD + cosine");  results["sgd_cosine"] = train_one_config("sgd", True)
print("\nRun D: SGD + const");   results["sgd_const"]  = train_one_config("sgd", False)
# Out:
# Run A: Adam + cosine
# Epoch 01 | loss=1.7444 | acc=0.308
# Epoch 02 | loss=1.4525 | acc=0.400
# Epoch 03 | loss=1.2231 | acc=0.489
# Epoch 04 | loss=1.0143 | acc=0.552
# Epoch 05 | loss=0.7877 | acc=0.608
#
# Run B: Adam + const
# Epoch 01 | loss=1.7510 | acc=0.338
# Epoch 02 | loss=1.4341 | acc=0.474
# Epoch 03 | loss=1.2947 | acc=0.515
# Epoch 04 | loss=1.1490 | acc=0.502
# Epoch 05 | loss=1.0588 | acc=0.501
#
# Run C: SGD + cosine
# Epoch 01 | loss=1.9574 | acc=0.371
# Epoch 02 | loss=1.6054 | acc=0.412
# Epoch 03 | loss=1.3961 | acc=0.439
# Epoch 04 | loss=1.2455 | acc=0.486
# Epoch 05 | loss=1.1212 | acc=0.493
#
# Run D: SGD + const
# Epoch 01 | loss=1.9550 | acc=0.374
# Epoch 02 | loss=1.6036 | acc=0.407
# Epoch 03 | loss=1.4271 | acc=0.439
# Epoch 04 | loss=1.2881 | acc=0.478
# Epoch 05 | loss=1.1886 | acc=0.488

# %% [markdown]
# ## 5) Plot & tiny results table

# %%
import matplotlib.pyplot as plt, pandas as pd
plt.figure()
for k,v in results.items():
    plt.plot(v["test_acc"], label=k)
plt.xlabel("epoch"); plt.ylabel("val_acc"); plt.title("CIFAR-10 (subset)"); plt.legend(); plt.show()
table = pd.DataFrame({k: [v["train_loss"][-1], v["test_acc"][-1]] for k,v in results.items()},
                     index=["final_train_loss","final_val_acc"]).T
print(table)
# Out:
#              final_train_loss  final_val_acc
# adam_cosine          0.787668         0.6080
# adam_const           1.058808         0.5009
# sgd_cosine           1.121250         0.4926
# sgd_const            1.188589         0.4883

# %% [markdown]
# ## 6) Reflection (3–5 sentences)
# - Which knobs did you choose and why?
# - What changed in curves/table?
# - What would you try next with 10× more compute?

# %% [markdown]
# I ran experiments with Adam and SGD optimizers, testing both constant and
# cosine annealing learning rate schedules (2x2 design). Adam + cosine annealing
# gave the highest accuracy at 60.8%. The training curves showed something
# interesting: cosine scheduling helped Adam a lot (+10.7% accuracy) but barely
# affected SGD (+0.5%). My guess is that Adam's adaptive learning rate works
# better with the cosine decay schedule. Also, Adam with constant learning rate
# plateaued after just 2 epochs, which shows why scheduling matters. If I had
# 10x more resources, I'd train for 50 epochs, experiment with learning rate
# warmup and weight decay, and try more augmentations plus optimizers like AdamW.

# %% [markdown]
# ## 7) **Project sketch** (≈150 words) — counts toward HW2 *Process* (5 pts)
# - **Question:** What are you trying to investigate?
# - **Data:** Which dataset(s) or data source?
# - **Metric(s):** What will you measure?
# - **One ablation:** What single change will you compare vs baseline?
# - **Constraints:** Acknowledge the course caps (≤5 epochs, ≤90 min GPU total, fixed subset allowed).
# - **Teammates (if any):** List names/NetIDs.
#
# > This is a draft. You can change it in the Dec 1 proposal.

# %% [markdown]
# **Project Sketch: Efficient Data Augmentation for Small Datasets**
#
# **Question:**
# Does combining multiple simple augmentations (MixUp, CutMix, RandAugment)
# improve classification accuracy on small datasets more than using them
# individually?
#
# **Data:**
# CIFAR-10 (50k training images, 10 classes). I will use a 10k subset for
# faster experimentation under the time constraint, ensuring balanced class
# distribution.
#
# **Metric(s):**
# Top-1 accuracy on the test set, as it directly measures classification
# performance and is standard for CIFAR-10 benchmarks.
#
# **Baseline & Ablation:**
# Baseline: ResNet-18 with standard augmentation (random crop + flip).
# Ablation: Test combined augmentations (MixUp + CutMix + RandAugment) vs
# baseline to measure if augmentation diversity improves generalization on
# limited data.
#
# **Constraints:**
# Training limited to 5 epochs and 90 minutes total GPU time. Will use 10k
# training subset to meet constraints.
